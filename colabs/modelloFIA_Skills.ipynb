# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Salary.csv')
data
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male                1      Software Engineer
# 1     28.0  Female                2           Data Analyst
# 2     45.0    Male                3                Manager
# 3     36.0  Female                1        Sales Associate
# 4     52.0    Male                2               Director
# ...    ...     ...              ...                    ...
# 6679  49.0  Female                3  Director of Marketing
# 6680  32.0    Male                0        Sales Associate
# 6681  30.0  Female                1      Financial Manager
# 6682  46.0    Male                2      Marketing Manager
# 6683  26.0  Female                0        Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior
# 0                     5.0   90000.0         UK       White       0
# 1                     3.0   65000.0        USA    Hispanic       0
# ...

# %%
# Selezionare solo le colonne richieste
columns_to_keep = ["Job Title", "Gender", "Age", "Education Level", "Years of Experience", "Senior"]
data_cleaned = data[columns_to_keep]

# Visualizzare le prime righe del dataset pulito
data_cleaned.head()
# Out:
#            Job Title  Gender   Age  Education Level  Years of Experience  \
# 0  Software Engineer    Male  32.0                1                  5.0
# 1       Data Analyst  Female  28.0                2                  3.0
# 2            Manager    Male  45.0                3                 15.0
# 3    Sales Associate  Female  36.0                1                  7.0
# 4           Director    Male  52.0                2                 20.0
#
#    Senior
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0

# %%
missing_values = data_cleaned.isnull().sum()
missing_values
# Out:
# Job Title              0
# Gender                 0
# Age                    0
# Education Level        0
# Years of Experience    0
# Senior                 0
# dtype: int64

# %%
# Trasformazione della colonna 'Gender' in valori booleani: Maschio = 1, Femmina = 0
gender_mapping = {'Male': 1, 'Female': 0}
data_cleaned['Gender'] = data_cleaned['Gender'].map(gender_mapping)

# Verifica delle modifiche
data_cleaned.head()
# Out:
# <ipython-input-5-bfa323e01b5f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Gender'] = data_cleaned['Gender'].map(gender_mapping)
#            Job Title  Gender   Age  Education Level  Years of Experience  \
# 0  Software Engineer       1  32.0                1                  5.0
# 1       Data Analyst       0  28.0                2                  3.0
# 2            Manager       1  45.0                3                 15.0
# 3    Sales Associate       0  36.0                1                  7.0
# 4           Director       1  52.0                2                 20.0
#
#    Senior
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0

# %%
job_title_counts = data_cleaned['Job Title'].value_counts()
job_title_counts
# Out:
# Software Engineer                 809
# Data Scientist                    515
# Data Analyst                      391
# Software Engineer Manager         376
# Product Manager                   323
#                                  ...
# Customer Support Specialist         1
# VP of Finance                       1
# Director of Product Management      1
# CEO                                 1
# Human Resources Director            1
# Name: Job Title, Length: 129, dtype: int64

# %%
single_occurrence_job_titles = job_title_counts[job_title_counts == 1]
single_occurrence_job_titles
# Out:
# Advertising Coordinator             1
# Software Manager                    1
# IT Project Manager                  1
# Quality Assurance Analyst           1
# Director of Sales and Marketing     1
# Account Executive                   1
# Director of Business Development    1
# Human Resources Specialist          1
# Director of Human Capital           1
# Data Entry Clerk                    1
# Social Media Man                    1
# VP of Operations                    1
# Product Development Manager         1
# Software Architect                  1
# HR Specialist                       1
# Director                            1
# Developer                           1
# Customer Service Rep                1
# IT Support                          1
# UX Researcher                       1
# Researcher                          1
# Customer Success Rep                1
# IT Manager                          1
# Business Intelligence Analyst       1
# Help Desk Analyst                   1
# ...

# %%
# Eliminazione dei titoli di lavoro che compaiono solo una volta
#cleaned_data_reduced = data_cleaned[~data_cleaned['Job Title'].isin(single_occurrence_job_titles.index)]
cleaned_data_reduced = data_cleaned[data_cleaned['Job Title'].isin(job_title_counts[job_title_counts > 1].index)]

# Dimensioni del dataset dopo l'eliminazione
reduced_dataset_shape = cleaned_data_reduced.shape
reduced_dataset_shape
# Out:
# (6631, 6)

# %%
cleaned_data_reduced
# Out:
#                   Job Title  Gender   Age  Education Level  \
# 0         Software Engineer       1  32.0                1
# 1              Data Analyst       0  28.0                2
# 2                   Manager       1  45.0                3
# 3           Sales Associate       0  36.0                1
# 5         Marketing Analyst       1  29.0                1
# ...                     ...     ...   ...              ...
# 6679  Director of Marketing       0  49.0                3
# 6680        Sales Associate       1  32.0                0
# 6681      Financial Manager       0  30.0                1
# 6682      Marketing Manager       1  46.0                2
# 6683        Sales Executive       0  26.0                0
#
#       Years of Experience  Senior
# 0                     5.0       0
# 1                     3.0       0
# 2                    15.0       1
# 3                     7.0       0
# 5                     2.0       0
# ...                   ...     ...
# ...

# %%
job_title_counts_new = cleaned_data_reduced['Job Title'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f1532aeae862> in <cell line: 1>()
# ----> 1 job_title_counts_new = cleaned_data_reduced['Job Title'].value_counts()
#
# NameError: name 'cleaned_data_reduced' is not defined

# %%
# Identificazione dei titoli di lavoro che compaiono meno di 20 volte nel dataset
less_than_20_occurrences = job_title_counts_new[job_title_counts_new < 20]
less_than_20_occurrences
# Out:
# Digital Marketing Specialist       15
# Social Media Manager               15
# Director of Operations             11
# Marketing Specialist               10
# Operations Analyst                  8
# Business Development Associate      7
# Customer Service Representative     6
# Accountant                          6
# HR Manager                          5
# Operations Coordinator              5
# Delivery Driver                     5
# Project Coordinator                 5
# Financial Advisor                   5
# UX Designer                         5
# Business Development Manager        5
# Data Engineer                       4
# Account Manager                     4
# Juniour HR Coordinator              3
# Juniour HR Generalist               3
# Scientist                           3
# Recruiter                           3
# Director of Human Resources         2
# Copywriter                          2
# Manager                             2
# Customer Service Manager            2
# ...

# %%
# Identificazione dei titoli di lavoro con meno di 10 occorrenze
titles_with_less_than_10_occurrences = job_title_counts_new[job_title_counts_new < 10].index

# Eliminazione delle righe con questi titoli di lavoro
cleaned_data_reduced_further = cleaned_data_reduced[~cleaned_data_reduced['Job Title'].isin(titles_with_less_than_10_occurrences)]

# Dimensioni del dataset dopo l'ulteriore eliminazione
further_reduced_dataset_shape = cleaned_data_reduced_further.shape
further_reduced_dataset_shape
# Out:
# (6521, 6)

# %%
# Raggruppamento e conteggio dei titoli di lavoro nel dataset ridotto
grouped_job_titles = cleaned_data_reduced_further['Job Title'].value_counts()
grouped_job_titles
# Out:
# Software Engineer               809
# Data Scientist                  515
# Data Analyst                    391
# Software Engineer Manager       376
# Product Manager                 323
# Project Engineer                317
# Marketing Manager               315
# Full Stack Engineer             304
# Back end Developer              242
# Front end Developer             239
# Sales Associate                 212
# Software Developer              186
# Marketing Coordinator           167
# Human Resources Manager         152
# Marketing Analyst               144
# Financial Manager               139
# Web Developer                   129
# Operations Manager              122
# Research Scientist              119
# HR Generalist                   104
# Director of Marketing            88
# Sales Representative             81
# Product Designer                 80
# Research Director                75
# Content Marketing Manager        73
# Product Marketing Manager        70
# ...

# %%
# Definizione di un nuovo dizionario di competenze generali ma distinte per ogni titolo di lavoro
distinct_skills_mapping = {
    "Software Engineer": "Sviluppo Software, Risoluzione di Problemi, Competenze Tecniche",
    "Software Developer": "Programmazione, Innovazione, Problem Solving",
    "Data Analyst": "Analisi Dati, Capacità Quantitative, Visualizzazione Dati",
    "Data Scientist": "Machine Learning, Statistica, Analisi Dati",
    "Sales Associate": "Vendita, Comunicazione, Relazioni con i Clienti",
    "Sales Manager": "Gestione Vendite, Strategia di Vendita, Leadership",
    "Marketing Analyst": "Analisi di Mercato, Digital Marketing, Comunicazione",
    "Marketing Manager": "Gestione Marketing, Strategia di Branding, Comunicazione",
    "Software Engineer Manager": "Leadership, Gestione delle Risorse, Comunicazione",
    "Product Manager": "Gestione del Prodotto, Analisi di Mercato, Gestione delle Parti Interessate",
    "Project Engineer": "Gestione di Progetti, Risoluzione di Problemi, Collaborazione Interdisciplinare",
    "Full Stack Engineer": "Sviluppo End-to-End, Ottimizzazione delle Performance, Collaborazione Interfunzionale",
    "Back End Developer":  "Sviluppo del Back End, Gestione dei Dati, Integrazione di Servizi Esterni",
    "Front End Developer": "Sviluppo dell'Interfaccia Utente, Responsive Design, Collaborazione con i Designer",
    "Software Developer": "Sviluppo Software, Risoluzione di Problemi, Innovazione",
    "Marketing Coordinator": "Pianificazione delle Campagne, Analisi dei Dati, Comunicazione Efficace",
    "Human Resources Manager": "Gestione delle Risorse Umane, Sviluppo Organizzativo, Risoluzione dei Conflitti",
    "Financial Manager": "Gestione Finanziaria, Analisi Finanziaria, Pianificazione Finanziaria Strategica",
    "Web Developer": "Sviluppo Web, Programmazione, Design Responsive",
    "Operations Manager": "Gestione Operativa, Pianificazione e Coordinamento, Gestione delle Risorse",
    "Research Scientist": "Ricerca, Metodologia Scientifica, Analisi dei Dati",
    "HR Generalist": "Gestione del Personale, Amministrazione delle Risorse Umane, Comunicazione Interna",
    "Director of Marketing": "Gestione del Marketing, Strategia di Marketing, Leadership",
    "Sales Representative": "Vendita, Comunicazione, Relazioni con i Clienti",
    "Product Designer": "Design Creativo, User-Centered Design, Prototipazione",
    "Research Director": "Gestione della Ricerca, Pianificazione Strategica, Leadership",
    "Content Marketing Manager": "Strategia di Content Marketing, Produzione di Contenuti, Analisi e Ottimizzazione",
    "Product Marketing Manager": "Strategia di Marketing Prodotto, Posizionamento di Mercato, Comunicazione del Prodotto",
    "Director of HR": "Gestione delle Risorse Umane, Strategia HR, Leadership",
    "Marketing Director": "Strategia di Marketing, Leadership, Analisi dei Risultati",
    "Sales Director": "Gestione delle Vendite, Leadership, 0Sviluppo Commerciale",
    "Director of Data Science": "Gestione Strategica dei Dati, Leadership, Analisi dei Dati Avanzata",
    "Receptionist": "Accoglienza e Customer Service, Comunicazione Efficace, Organizzazione e Gestione delle Attività",
    "Financial Analyst": "Analisi Finanziaria, Modellazione Finanziaria, Comunicazione dei Risultati",
    "Digital Marketing Manager": "Strategia di Marketing Digitale, Gestione del Team, Analisi e Ottimizzazione",
    "Human Resources Coordinator": "Assistenza alle Risorse Umane, Comunicazione Interna, Gestione dei Record",
    "Sales Executive": "Vendita, Negoziazione, Pianificazione delle Vendite",
    "Project Manager": "Gestione di Progetto, Leadership, Comunicazione Efficace",
    "HR Coordinator": "Supporto Operativo HR, Comunicazione Interna, Gestione dei Record",
    "Graphic Designer": "Design Creativo, Software di Design, Comunicazione Visiva",
    "Business Analyst": "Analisi dei Dati, Gestione dei Processi Aziendali, Comunicazione Efficace",
    "Social Media Manager": "Gestione dei Social Media, Strategia di Social Media, Analisi dei Dati Social",
    "Digital Marketing Specialist": "Pianificazione e Strategia Digitale, Analisi dei Dati, Conoscenza delle Piattaforme Digitali",
    "Director of Operations": "Gestione Operativa, Pianificazione Strategica, Leadership",
    "Marketing Specialist": "Esecuzione di Campagne, Analisi dei Dati, Comunicazione di Marketing",
}

# Definizione della funzione per assegnare competenze basate sul titolo di lavoro
def assign_distinct_skills(job_title):
    # Utilizza il dizionario per ottenere le competenze basate sul titolo di lavoro, con fallback su "Competenze Generali"
    return distinct_skills_mapping.get(job_title, "Competenze Generali")

# Applicazione della funzione alla colonna 'Job Title' per aggiornare la colonna 'Skills'
cleaned_data_reduced_further['Skills'] = cleaned_data_reduced_further['Job Title'].apply(assign_distinct_skills)

# Visualizzazione dei risultati aggiornati
cleaned_data_reduced_further.head()
# Out:
# <ipython-input-18-922783aa1c67>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data_reduced_further['Skills'] = cleaned_data_reduced_further['Job Title'].apply(assign_distinct_skills)
#            Job Title  Gender   Age  Education Level  Years of Experience  \
# 0  Software Engineer       1  32.0                1                  5.0
# 1       Data Analyst       0  28.0                2                  3.0
# 3    Sales Associate       0  36.0                1                  7.0
# 5  Marketing Analyst       1  29.0                1                  2.0
# 6    Product Manager       0  42.0                2                 12.0
#
#    Senior                                             Skills
# ...

# %%
#libreria che permette di binarizzare la colonna skills
from sklearn.preprocessing import MultiLabelBinarizer

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
import numpy as np



# Estrazione e trasformazione delle competenze in un formato adatto per MultiLabelBinarizer
skills_series = cleaned_data_reduced_further['Skills'].str.split(', ').apply(lambda x: x if isinstance(x, list) else [])

# Inizializzazione e applicazione di MultiLabelBinarizer per trasformare le competenze in colonne binarie
mlb = MultiLabelBinarizer()
skills_encoded = mlb.fit_transform(skills_series)

# Creazione di un DataFrame per le competenze codificate l'attributo mlb.classes serve a dare i nomi alle colonne
skills_df = pd.DataFrame(skills_encoded, columns=mlb.classes_)

# Codifica della variabile target 'Job Title'
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(cleaned_data_reduced_further['Job Title'])

# Preparazione delle altre feature escludendo 'Skills'
X_other_features = cleaned_data_reduced_further.drop(columns=['Skills', 'Job Title'])

# Riunione delle nuove colonne delle competenze con le altre feature numeriche/categoriche, escludendo le righe con indice in eccesso
X_final = pd.concat([X_other_features.reset_index(drop=True), skills_df.iloc[:X_other_features.shape[0]].reset_index(drop=True)], axis=1)

# Controllo delle dimensioni per assicurarsi che corrispondano
assert X_final.shape[0] == X_other_features.shape[0], "Mismatch in row count"

# Divisione del dataset finale in set di training e test
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(X_final, y, test_size=0.2, random_state=42)

# Inizializzazione e addestramento del modello di classificazione
randomTree_model = RandomForestClassifier(random_state=None)
decisionTree_model = DecisionTreeClassifier()

# Addestramento del modello con il dataset finale
randomTree_model.fit(X_train_final, y_train_final)
decisionTree_model.fit(X_train_final, y_train_final)

# Predizione sul set di test finale
y_pred_final_r = randomTree_model.predict(X_test_final)
y_pred_final_d = decisionTree_model.predict(X_test_final)

# Applicazione della cross-validation
# Nota: X_train_final e y_train_final sono stati preparati in precedenza
# Assicurati che il dataset sia completo e pronto per la cross-validation
scores_accuracy_r = cross_val_score(randomTree_model, X_train_final, y_train_final, cv=5, scoring='accuracy')
scores_precision_r = cross_val_score(randomTree_model, X_train_final, y_train_final, cv=5, scoring='precision_macro')
scores_recall_r = cross_val_score(randomTree_model, X_train_final, y_train_final, cv=5, scoring='recall_macro')

scores_accuracy_d = cross_val_score(decisionTree_model, X_train_final, y_train_final, cv=5, scoring='accuracy')
scores_precision_d = cross_val_score(decisionTree_model, X_train_final, y_train_final, cv=5, scoring='precision_macro')
scores_recall_d = cross_val_score(decisionTree_model, X_train_final, y_train_final, cv=5, scoring='recall_macro')

# Calcolo della media delle metriche di performance
mean_accuracy_r = np.mean(scores_accuracy_r)
mean_precision_r = np.mean(scores_precision_r)
mean_recall_r = np.mean(scores_recall_r)

mean_accuracy_d = np.mean(scores_accuracy_d)
mean_precision_d = np.mean(scores_precision_d)
mean_recall_d = np.mean(scores_recall_d)

print("Random tree classifier result")
print(mean_accuracy_r, mean_precision_r, mean_recall_r)

print("Decision tree result")
print(mean_accuracy_d, mean_precision_d, mean_recall_d)
# Out:
# Random tree classifier result
# 0.9827457635835326 0.9883228887350624 0.9872235717498874
# Decision tree result
# 0.9825538253564172 0.9887878538608476 0.9820978657469887
